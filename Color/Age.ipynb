# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv("Age.csv")

# %%
df
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    42000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='Age',y='Premium',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['Age']],df['Premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[22]])
# Out:
# C:\Users\prasa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15660.])

# %%
reg.predict([[55]])
# Out:
# C:\Users\prasa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([74400.])

# %%
reg.predict([[33]])
# Out:
# C:\Users\prasa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35240.])

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# np.float64(-23500.0)
