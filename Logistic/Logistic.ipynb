# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib

# %%
data=pd.read_csv("new.csv")

# %% [markdown]
# data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['age']],data.bought_insurance,train_size=0.8)

# %%
x_test
# Out:
#     age
# 7    60
# 1    25
# 14   49
# 13   29
# 15   55
# 2    47

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 7    60
# 1    25
# 14   49
# 13   29
# 15   55
# 2    47

# %%
y_predicted=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.09120307, 0.90879693],
#        [0.84146897, 0.15853103],
#        [0.25886531, 0.74113469],
#        [0.77130358, 0.22869642],
#        [0.15031369, 0.84968631],
#        [0.30467825, 0.69532175]])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([1, 0, 1, 0, 1, 1])

# %%
x_test
# Out:
#     age
# 7    60
# 1    25
# 14   49
# 13   29
# 15   55
# 2    47
