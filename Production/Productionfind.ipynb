# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Production.csv")

# %%
data
# Out:
#   Experience Performance Qualifications Training Promote
# 0       High   Excellent             PG      Yes     Yes
# 1       High        Good             PG      Yes     Yes
# 2     Medium        Good             PG      Yes     Yes
# 3        Low     Average             UG       No      No
# 4     Medium     Average             UG       No      No
# 5        Low        Poor             UG       No      No

# %%
concepts=np.array(data)[:,:-1]

# %%
concepts
# Out:
# array([['High', 'Excellent', 'PG', 'Yes'],
#        ['High', 'Good', 'PG', 'Yes'],
#        ['Medium', 'Good', 'PG', 'Yes'],
#        ['Low', 'Average', 'UG', 'No'],
#        ['Medium', 'Average', 'UG', 'No'],
#        ['Low', 'Poor', 'UG', 'No']], dtype=object)

# %%
target=np.array(data)[:,-1]

# %% [raw]
# target

# %%
target
# Out:
# array(['Yes', 'Yes', 'Yes', 'No', 'No', 'No'], dtype=object)

# %%
def train(con,tar):
    for i,val in enumerate(tar):
        if val=='yes':
            specific_h=con[i].copy()
            break
    for i,val in enumerate(con):
        if tar[i]=='yes':
            for x in range(len(specific_h)):
                if val[x]!=specific_h[x]:
                    specific_h[x]='?'
                else:
                    pass
    return specific_h

# %%
print(train(concepts,target))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(train(concepts,target))
#
# Cell In[16], line 13, in train(con, tar)
#      11             else:
#      12                 pass
# ---> 13 return specific_h
#
# UnboundLocalError: cannot access local variable 'specific_h' where it is not associated with a value
